# %% [markdown]
# # Hydrating Tweets

# %%
from google.colab import auth
from googleapiclient.discovery import build


auth.authenticate_user()
gcs_service = build('storage', 'v1')

project_id = 'cs-1699-group-project'
# !gcloud config set project {project_id}
request = gcs_service.objects().list(bucket='geotag_tweets')
#response = request.execute()

#print(response)

items = request["items"]
items = response["items"]
for i in items[:3]:
#for i in items:
  # !gsutil cp gs://i['id'] /i['name'].csv
# !cat /june4_june5-2020-09-21T00:28:41.263Z.csv
# Out:
# Updated property [core/project].
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-8-bcaeb11fcbef> in <module>()
#       9 get_ipython().system('gcloud config set project {project_id}')
#      10 request = gcs_service.objects().list(bucket='geotag_tweets')
# ---> 11 response = request.execute()
#      12
#      13 #print(response)
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     896             callback(resp)
#     897         if resp.status >= 300:
# ...

# %%
listt = ['1','2','3','4','5','6']
for item in listt[:3]:
  print(item)
# Out:
# 1
# 2
# 3

# %%
#public interface GcsService

request = gcs_service.objects().list(bucket='geotag_tweets')
response = request.execute()
items = response["items"]
#print(items["URI"])
for i in items:
  print(i['id'])
#print(response["items"])
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-6-ac2a7122bce1> in <module>()
#       2
#       3 request = gcs_service.objects().list(bucket='geotag_tweets')
# ----> 4 response = request.execute()
#       5 items = response["items"]
#       6 #print(items["URI"])
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# /usr/local/lib/python3.6/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     896             callback(resp)
#     897         if resp.status >= 300:
# --> 898             raise HttpError(resp, content, uri=self.uri)
# ...
